# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('agri_ds.csv')

# %%
df
# Out:
#      season  pH value  temperature  humidity  rainfall  yield  water   crop
# 0         1       5.5           26        36    143.00   3.99      80  Rice
# 1         1       5.7           29        37     99.00   4.26      80  Rice
# 2         1       5.9           22        38    110.00   4.64      80  Rice
# 3         1       6.0           27        39    107.00   3.61      80  Rice
# 4         1       6.2           20        40    137.00   4.65      80  Rice
# ..      ...       ...          ...       ...       ...    ...     ...   ...
# 179       0       6.3           22        50     22.00   0.84      50  Urad
# 180       1       6.8           34        51      2.87   0.52      50  Urad
# 181       0       7.3           33        52    121.00   0.84      50  Urad
# 182       2       7.0           31        53    106.40   0.85      50  Urad
# 183       2       7.5           27        54     25.40   0.69      50  Urad
#
# [184 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   season       184 non-null    int64
#  1   pH value     184 non-null    float64
#  2   temperature  184 non-null    int64
#  3   humidity     184 non-null    int64
#  4   rainfall     184 non-null    float64
#  5   yield        184 non-null    float64
#  6   water        184 non-null    int64
#  7   crop         184 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 11.6+ KB

# %%
df['crop'].unique()
# Out:
# array(['Rice', 'Maize', 'Jowar', 'Bajra', 'Ragi', 'Arhar', 'Sugarcane',
#        'Groundnut', 'Sesame', 'Cotton', 'Sunflower', 'Banana',
#        'Cashewnut', 'Castorseed', 'Coriander', 'Coconut', 'Chilly',
#        'Gram', 'Horsegram', 'Greengram', 'Masoor ', 'Onion',
#        'Smallmillets', 'Sweet potato', 'Tapioca', 'Turmeric', 'Urad'],
#       dtype=object)

# %%
sns.pairplot(df,hue='crop',palette='coolwarm')

# %%
sns.barplot(x='crop',y='pH value',data=df)
# Out:
# <AxesSubplot:xlabel='crop', ylabel='pH value'>

# %%
df['season'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
m=df[df['season']==0]

# %%
m['yield'].max()
# Out:
# 15575.23

# %%
n=df[df['season']==1]

# %%
n['yield'].max()
# Out:
# 5.48

# %%
a=df[df['season']==2]

# %%
a['yield'].max()
# Out:
# 0.85

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
m
# Out:
#      season  pH value  temperature  humidity  rainfall  yield  water   \
# 7         0       5.8           24        40      49.0   3.08      50
# 8         0       5.9           19        41      80.0   3.96      50
# 9         0       6.1           29        42      73.0   4.30      50
# 10        0       6.3           20        43      66.0   2.10      50
# 11        0       6.6           27        44      52.0   4.46      50
# ..      ...       ...          ...       ...       ...    ...     ...
# 175       0       4.9           30        65     135.0   4.00      75
# 176       0       7.5           31        90     145.0   3.80      85
# 177       0       4.5           25        48       7.4   0.38      50
# 179       0       6.3           22        50      22.0   0.84      50
# 181       0       7.3           33        52     121.0   0.84      50
#
#          crop
# 7       Maize
# 8       Maize
# 9       Maize
# 10      Maize
# 11      Maize
# ..        ...
# 175  Turmeric
# ...

# %%
n
# Out:
#      season  pH value  temperature  humidity  rainfall  yield  water   \
# 0         1       5.5           26        36    143.00   3.99      80
# 1         1       5.7           29        37     99.00   4.26      80
# 2         1       5.9           22        38    110.00   4.64      80
# 3         1       6.0           27        39    107.00   3.61      80
# 4         1       6.2           20        40    137.00   4.65      80
# 5         1       6.3           21        41    155.00   4.14      80
# 6         1       6.5           30        42    149.00   3.64      80
# 36        1       6.8           19        45     62.00   0.81      35
# 38        1       7.1           29        84     64.00   0.67      35
# 50        1       7.9           26        42    102.00   1.83      50
# 52        1       8.3           23        44     86.00   2.00      50
# 71        1       6.1           19        63     49.00   1.14      50
# ...

# %%
a
# Out:
#      season  pH value  temperature  humidity  rainfall  yield  water   crop
# 120       2       6.8           15        54      35.0   0.59      80  Gram
# 122       2       7.3           27        56      43.0   0.64      50  Gram
# 124       2       6.9           23        58      31.0   0.61      50  Gram
# 182       2       7.0           31        53     106.4   0.85      50  Urad
# 183       2       7.5           27        54      25.4   0.69      50  Urad

# %%
m_maize=m[m['crop']=='Maize']
m_maize['yield'].mean()
# Out:
# 4.345714285714285

# %%
d={}
for i in m['crop'].unique():
    mr=m[m['crop']==i]
    mean1=mr['yield'].mean()
    print(i,mean1)
    d[i]=int(mean1)
# Out:
# Maize 4.345714285714285
# Jowar 1.645714285714286
# Bajra 2.238571428571429
# Ragi 2.5985714285714283
# Arhar 0.8560000000000001
# Sugarcane 92.67571428571428
# Groundnut 1.886
# Sesame 0.5185714285714286
# Cotton 1.682857142857143
# Sunflower 1.3359999999999999
# Banana 44.67857142857143
# Cashewnut 0.3614285714285714
# Castorseed 0.32499999999999996
# Coriander 0.5014285714285714
# Coconut 14670.08
# Chilly 0.5385714285714286
# Gram 0.6075
# Horsegram 0.5485714285714286
# Greengram 0.5128571428571428
# Onion 8.865714285714285
# Smallmillets 1.2085714285714286
# Sweet potato 21.58428571428571
# Tapioca 38.86571428571428
# Turmeric 4.586666666666667
# Urad 0.6866666666666666

# %%
d
# Out:
# {'Maize': 4,
#  'Jowar': 1,
#  'Bajra': 2,
#  'Ragi': 2,
#  'Arhar': 0,
#  'Sugarcane': 92,
#  'Groundnut': 1,
#  'Sesame': 0,
#  'Cotton': 1,
#  'Sunflower': 1,
#  'Banana': 44,
#  'Cashewnut': 0,
#  'Castorseed': 0,
#  'Coriander': 0,
#  'Coconut': 14670,
#  'Chilly': 0,
#  'Gram': 0,
#  'Horsegram': 0,
#  'Greengram': 0,
#  'Onion': 8,
#  'Smallmillets': 1,
#  'Sweet potato': 21,
#  'Tapioca': 38,
#  'Turmeric': 4,
#  'Urad': 0}

# %%
plt.bar(d.keys(),d.values())
# Out:
# <BarContainer object of 25 artists>

# %%
plt.pie(d.values(),labels=d.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x2441b88e520>,
# ...
#  [Text(1.0999996082644115, 0.0009283416081003377, 'Maize'),
#   Text(1.0999980168390613, 0.0020887676109166073, 'Jowar'),
#   Text(1.0999964743813773, 0.0027850221794691477, 'Bajra'),
#   Text(1.0999937322361637, 0.003713359820323336, 'Ragi'),
#   Text(1.0999920673633958, 0.0041775276902653305, 'Arhar'),
#   Text(1.099703763245603, 0.025527105269868944, 'Sugarcane'),
#   Text(1.0989912146923673, 0.047098938724726334, 'Groundnut'),
#   Text(1.0989812529792125, 0.047330810263929456, 'Sesame'),
#   Text(1.0989712423444566, 0.04756267969618213, 'Cotton'),
#   Text(1.0989510743119255, 0.04802641219854922, 'Sunflower'),
#   Text(1.0984455676269091, 0.05845797602378394, 'Banana'),
#   Text(1.0978555529681528, 0.06865263882030762, 'Cashewnut'),
#   Text(1.0978555529681528, 0.06865263882030762, 'Castorseed'),
#   Text(1.0978555529681528, 0.06865263882030762, 'Coriander'),
#   Text(-1.0998585876192015, -0.017637665386764825, 'Coconut'),
# ...

# %%
d={}
for i in n['crop'].unique():
    m1=n[n['crop']==i]
    mean2=m1['yield'].mean()
    print(i,mean2)
    d[i]=int(mean2)
# Out:
# Rice 4.132857142857143
# Arhar 0.74
# Groundnut 1.915
# Sunflower 1.065
# Castorseed 0.39
# Masoor  1.15
# Turmeric 5.48
# Urad 0.495

# %%
d
# Out:
# {'Rice': 4,
#  'Arhar': 0,
#  'Groundnut': 1,
#  'Sunflower': 1,
#  'Castorseed': 0,
#  'Masoor ': 1,
#  'Turmeric': 5,
#  'Urad': 0}

# %%
plt.bar(d.keys(),d.values())
# Out:
# <BarContainer object of 8 artists>

# %%
plt.pie(d.values(),labels=d.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x2441b99e340>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'Rice'),
#   Text(-0.5500000594609755, 0.9526279098330699, 'Arhar'),
#   Text(-0.7778175139235952, 0.7778174046868056, 'Groundnut'),
#   Text(-1.0625184333522957, 0.2847008584226317, 'Sunflower'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Castorseed'),
#   Text(-1.062518380041041, -0.28470105738293683, 'Masoor '),
#   Text(0.2847010325128994, -1.0625183867049497, 'Turmeric'),
#   Text(1.0999999999999988, 5.149471657675648e-08, 'Urad')])

# %%
d={}
for i in a['crop'].unique():
    m3=a[a['crop']==i]
    mean3=m3['yield'].mean()
    print(i,mean3)
    d[i]=int(mean3)
# Out:
# Gram 0.6133333333333333
# Urad 0.77

# %%
d
# Out:
# {'Gram': 0, 'Urad': 0}

# %%
plt.bar(d.keys(),d.values())
# Out:
# <BarContainer object of 2 artists>

# %%
x=df.iloc[:,0:7]

# %%
y=df['crop']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

# %%
xtrain
# Out:
#      season  pH value  temperature  humidity  rainfall  yield  water
# 47        0       7.9           32        83     267.0  80.30      65
# 126       0       6.5           24        60      50.0   0.46      50
# 54        0       8.4           35        46      90.0   2.12      50
# 24        0       5.8           26        76      33.0   1.98      45
# 32        0       6.1           26        45     120.0   3.05      65
# ..      ...       ...          ...       ...       ...    ...     ...
# 146       0       6.3           26        67      63.0   8.84      25
# 100       0       7.1           23        69     260.0   0.47      80
# 0         1       5.5           26        36     143.0   3.99      80
# 57        0       5.9           25        49      27.0   0.45      60
# 102       0       7.3           29        71     190.0   0.35      85
#
# [128 rows x 7 columns]

# %%
ytrain
# Out:
# 47     Sugarcane
# 126    Horsegram
# 54     Groundnut
# 24         Bajra
# 32          Ragi
#          ...
# 146        Onion
# 100    Coriander
# 0           Rice
# 57        Sesame
# 102    Coriander
# Name: crop, Length: 128, dtype: object

# %%
xtest
# Out:
#      season  pH value  temperature  humidity  rainfall     yield  water
# 134       0       7.2           33        49      55.0      0.27      60
# 149       0       5.5           20        69      50.0      0.62      60
# 67        0       6.2           30        59      62.0      1.67      83
# 65        0       6.1           23        57      54.0      2.10      75
# 34        0       7.5           30        47     101.0      3.14      65
# 42        0       5.0           31        83     250.0     67.79      65
# 46        0       7.2           31        82     299.0     97.97      65
# 124       2       6.9           23        58      31.0      0.61      50
# 59        0       6.8           33        51      24.0      0.45      60
# 19        0       6.8           31        44      49.0      2.54      60
# 129       0       7.3           32        65      65.0      0.40      60
# 85        0       5.8           28        61     498.0      0.43      80
# ...

# %%
ytest
# Out:
# 134       Greengram
# 149    Smallmillets
# 67           Cotton
# 65           Cotton
# 34             Ragi
# 42        Sugarcane
# 46        Sugarcane
# 124            Gram
# 59           Sesame
# 19            Jowar
# 129       Horsegram
# 85        Cashewnut
# 66           Cotton
# 104       Coriander
# 50        Groundnut
# 113          Chilly
# 36            Arhar
# 159    Sweet potato
# 16            Jowar
# 89        Cashewnut
# 5              Rice
# 68           Cotton
# 115          Chilly
# 106         Coconut
# 131       Horsegram
# 173        Turmeric
# 156    Sweet potato
# 72        Sunflower
# 109         Coconut
# 164         Tapioca
# 10            Maize
# 14            Jowar
# 171        Turmeric
# 83           Banana
# 20            Jowar
# 128       Horsegram
# 26            Bajra
# 97       Castorseed
# 177            Urad
# 75        Sunflower
# 3              Rice
# 158    Sweet potato
# 79           Banana
# 112          Chilly
# 114          Chilly
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
p=rfc.predict(xtest)

# %%
accuracy_score(p,ytest)*100
# Out:
# 82.14285714285714

# %%
p1=rfc.predict(xtrain)

# %%
accuracy_score(p1,ytrain)*100
# Out:
# 100.0
