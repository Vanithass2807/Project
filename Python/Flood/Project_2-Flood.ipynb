# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('kerala.csv')

# %%
df
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %%
df.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JAN                 0
# FEB                 0
# MAR                 0
# APR                 0
# MAY                 0
# JUN                 0
# JUL                 0
# AUG                 0
# SEP                 0
# OCT                 0
# NOV                 0
# DEC                 0
#  ANNUAL RAINFALL    0
# FLOODS              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %%
x=df[df['YEAR']==1930]

# %%
x
# Out:
#    SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY    JUN    JUL    AUG  \
# 29      KERALA  1930  10.8  10.8  39.0  102.7  404.9  633.1  401.7  273.4
#
#       SEP    OCT    NOV   DEC   ANNUAL RAINFALL FLOODS
# 29  411.5  433.9  207.0  89.2            3018.0    YES

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.barplot(data=x)
# Out:
# <AxesSubplot:>

# %%
x=x.drop(['YEAR','SUBDIVISION','FLOODS',' ANNUAL RAINFALL'],axis=1)

# %%
sns.barplot(data=x)
# Out:
# <AxesSubplot:>

# %%
n=int(input('Enter a year between  1901 to 2018:'))
print('enter 0 to exit')
while n!=0:
    x=df[df['YEAR']==n]
    x=x.drop(['YEAR','SUBDIVISION','FLOODS',' ANNUAL RAINFALL'],axis=1)
    sns.barplot(data=x)
    break
# Out:
# Enter a year between  1901 to 2018:1930
# enter 0 to exit

# %%
n=int(input('Enter a year between  1901 to 2018:'))
print('enter 0 to exit')
while n!=0:
    x=df[df['YEAR']==n]
    x=x.drop(['YEAR','SUBDIVISION','FLOODS',' ANNUAL RAINFALL'],axis=1)
    sns.barplot(data=x)
    break
# Out:
# Enter a year between  1901 to 2018:1995
# enter 0 to exit

# %%
print('enter 0 to exit')
n=int(input('Enter a year between  1901 to 2018:'))
while n!=0:
    x=df[df['YEAR']==n]
    x=x.drop(['YEAR','SUBDIVISION','FLOODS',' ANNUAL RAINFALL'],axis=1)
    sns.barplot(data=x)
    break
# Out:
# enter 0 to exit
# Enter a year between  1901 to 2018:2002

# %%
print('enter 0 to exit')
n=int(input('Enter a year between  1901 to 2018:'))
while n!=0:
    x=df[df['YEAR']==n]
    x=x.drop(['YEAR','SUBDIVISION','FLOODS',' ANNUAL RAINFALL'],axis=1)
    sns.barplot(data=x)
    break
# Out:
# enter 0 to exit
# Enter a year between  1901 to 2018:0

# %%
a=df[df['YEAR']==2002]
b=df.FLOODS
sns.barplot(x='YEAR',y='FLOODS',data=df)
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='FLOODS'>

# %%
x=df.iloc[:,2:14]  #slicing method of columns

# %%
x
# Out:
#       JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG    SEP    OCT  \
# 0    28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5  197.7  266.9
# 1     6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8  491.6  358.4
# 2     3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2  341.8  354.1
# 3    23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8  222.7  328.1
# 4     1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6  217.2  383.5
# ..    ...   ...   ...    ...    ...     ...     ...     ...    ...    ...
# 113   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9  298.8  355.5
# 114   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2  292.9  308.1
# 115   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5  173.2  225.9
# 116   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8  209.5  192.4
# 117  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9  423.6  356.1
#
#        NOV    DEC
# 0    350.8   48.4
# 1    158.3  121.5
# 2    157.0   59.0
# ...

# %%
y=df['FLOODS']

# %%
y
# Out:
# 0      YES
# 1      YES
# 2      YES
# 3      YES
# 4       NO
#       ...
# 113    YES
# 114     NO
# 115     NO
# 116     NO
# 117    YES
# Name: FLOODS, Length: 118, dtype: object

# %%
x.min()
# Out:
# JAN      0.0
# FEB      0.0
# MAR      0.1
# APR     13.1
# MAY     53.4
# JUN    196.8
# JUL    167.5
# AUG    178.6
# SEP     41.3
# OCT     68.5
# NOV     31.5
# DEC      0.1
# dtype: float64

# %%
x.max()
# Out:
# JAN      83.5
# FEB      79.0
# MAR     217.2
# APR     238.0
# MAY     738.8
# JUN    1098.2
# JUL    1526.5
# AUG    1398.9
# SEP     526.7
# OCT     567.9
# NOV     365.6
# DEC     202.3
# dtype: float64

# %%
# more rain blue,moderate rain green,less rain red

# %%
from sklearn import preprocessing as p

# %%
minmax=p.MinMaxScaler(feature_range=(0,1))

# %%
f=minmax.fit(x)

# %%
f
# Out:
# MinMaxScaler()

# %%
x1=f.transform(x)

# %%
x1
# Out:
# array([[0.34371257, 0.56582278, 0.23721787, ..., 0.39727673, 0.95570189,
#         0.2388724 ],
#        [0.08023952, 0.03291139, 0.26347305, ..., 0.5804966 , 0.37952709,
#         0.60039565],
#        [0.03832335, 0.23544304, 0.01381852, ..., 0.57188626, 0.37563604,
#         0.29129575],
#        ...,
#        [0.02874251, 0.04810127, 0.16490097, ..., 0.31517821, 0.28105358,
#         0.11622156],
#        [0.02275449, 0.08607595, 0.04053432, ..., 0.24809772, 0.18258007,
#         0.18793274],
#        [0.34850299, 0.65949367, 0.22339936, ..., 0.57589107, 0.28105358,
#         0.3214639 ]])

# %%
x
# Out:
#       JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG    SEP    OCT  \
# 0    28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5  197.7  266.9
# 1     6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8  491.6  358.4
# 2     3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2  341.8  354.1
# 3    23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8  222.7  328.1
# 4     1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6  217.2  383.5
# ..    ...   ...   ...    ...    ...     ...     ...     ...    ...    ...
# 113   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9  298.8  355.5
# 114   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2  292.9  308.1
# 115   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5  173.2  225.9
# 116   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8  209.5  192.4
# 117  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9  423.6  356.1
#
#        NOV    DEC
# 0    350.8   48.4
# 1    158.3  121.5
# 2    157.0   59.0
# ...

# %%
c=x.columns

# %%
df1=pd.DataFrame(x1,columns=c)  #for replacing the names correctly

# %%
df1
# Out:
#           JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 0    0.343713  0.565823  0.237218  0.653179  0.176977  0.696472  0.423473
# 1    0.080240  0.032911  0.263473  0.314807  0.118325  0.215332  0.763429
# 2    0.038323  0.235443  0.013819  0.313473  0.286402  0.401376  0.629139
# 3    0.283832  0.037975  0.147858  0.259671  0.265976  1.000000  0.410596
# 4    0.014371  0.282278  0.042837  0.412628  0.306245  0.724872  0.259750
# ..        ...       ...       ...       ...       ...       ...       ...
# 113  0.055090  0.130380  0.081990  0.367274  0.288299  0.285778  0.375497
# 114  0.037126  0.073418  0.230309  0.893731  0.216516  0.406923  0.175497
# 115  0.028743  0.048101  0.164901  0.577590  0.194047  0.360994  0.180132
# 116  0.022754  0.086076  0.040534  0.135616  0.175226  0.334702  0.111921
# 117  0.348503  0.659494  0.223399  0.459315  0.190254  0.475483  0.648271
#
#           AUG       SEP       OCT       NOV       DEC
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df1,y,test_size=0.3)

# %%
xtrain
# Out:
#           JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 5    0.319760  0.093671  0.045140  0.205869  0.156697  0.241957  0.578882
# 72   0.000000  0.003797  0.056195  0.526456  0.097024  0.466164  0.306107
# 28   0.153293  0.377215  0.270843  0.878613  0.138022  0.831817  0.497792
# 66   0.171257  0.001266  0.112851  0.253446  0.279399  0.382627  0.422296
# 31   0.001198  0.244304  0.131276  0.444197  0.865334  0.159973  0.403900
# ..        ...       ...       ...       ...       ...       ...       ...
# 94   0.123353  0.082278  0.171350  0.541574  0.440910  0.329044  0.393672
# 14   0.202395  0.297468  0.196223  0.413072  0.147505  0.553916  0.447461
# 11   0.022754  0.189873  0.051129  0.487328  0.239130  0.833592  0.490140
# 109  0.222754  0.012658  0.144173  0.559360  0.200175  0.522188  0.339588
# 79   0.000000  0.011392  0.095348  0.452201  0.075722  0.609164  0.431567
#
#           AUG       SEP       OCT       NOV       DEC
# ...

# %%
ytrain
# Out:
# 5       NO
# 72      NO
# 28     YES
# 66      NO
# 31     YES
#       ...
# 94      NO
# 14     YES
# 11     YES
# 109    YES
# 79      NO
# Name: FLOODS, Length: 82, dtype: object

# %%
xtest
# Out:
#           JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 108  0.039521  0.018987  0.287886  0.248555  0.201634  0.267806  0.557322
# 24   0.049102  0.208861  0.353754  0.357048  0.298804  0.545818  0.313466
# 23   0.231138  0.036709  0.306310  0.435305  0.192588  0.904038  1.000000
# 59   0.112575  0.106329  0.204053  0.860382  0.709950  0.314511  0.429286
# 35   0.014371  0.208861  0.533855  0.092930  0.602714  0.470379  0.371302
# 99   0.140120  0.731646  0.098572  0.369942  0.103735  0.484801  0.129286
# 89   0.178443  0.060759  0.082450  0.127612  0.634812  0.368094  0.344297
# 115  0.028743  0.048101  0.164901  0.577590  0.194047  0.360994  0.180132
# 1    0.080240  0.032911  0.263473  0.314807  0.118325  0.215332  0.763429
# 13   0.008383  0.086076  0.082911  0.087150  0.161657  0.408809  0.507873
# 60   0.164072  0.396203  0.052050  0.360160  0.652320  0.896827  0.720383
# 64   0.108982  0.011392  0.129894  0.429969  0.235045  0.444753  0.218985
# ...

# %%
ytest
# Out:
# 108     NO
# 24     YES
# 23     YES
# 59     YES
# 35     YES
# 99      NO
# 89      NO
# 115     NO
# 1      YES
# 13      NO
# 60     YES
# 64      NO
# 74     YES
# 37      NO
# 63      NO
# 57     YES
# 104    YES
# 100     NO
# 70     YES
# 95      NO
# 102     NO
# 101     NO
# 7       NO
# 69      NO
# 40     YES
# 16      NO
# 82      NO
# 50      NO
# 15     YES
# 98      NO
# 86      NO
# 105    YES
# 41     YES
# 49     YES
# 62      NO
# 34      NO
# Name: FLOODS, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier() #fit()- is used to train the ml

# %%
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
p=rfc.predict(xtest)

# %%
p
# Out:
# array(['YES', 'YES', 'YES', 'YES', 'YES', 'NO', 'NO', 'NO', 'YES', 'NO',
#        'YES', 'NO', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'YES', 'YES', 'NO', 'YES', 'YES', 'NO',
#        'NO', 'YES', 'YES', 'YES', 'YES', 'NO'], dtype=object)

# %%
accuracy_score(p,ytest)*100
# Out:
# 83.33333333333334

# %%
p1=rfc.predict(xtrain)

# %%
accuracy_score(p1,ytrain)*100
# Out:
# 100.0

# %%
from sklearn import neighbors

# %%
clf=neighbors.KNeighborsClassifier()

# %%
clf.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
p=clf.predict(xtest)

# %%
accuracy_score(p,ytest)*100
# Out:
# 83.33333333333334

# %%
p1=clf.predict(xtrain)

# %%
accuracy_score(p1,ytrain)*100
# Out:
# 91.46341463414635

# %%
l=[26.7,37.1,121,537,580.8,590,639,620,582.5,325,280.3,121.5]

# %%
rfc.predict([l])
# Out:
# C:\Users\91636\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['YES'], dtype=object)

# %%
import joblib

# %%
joblib.dump(clf,'knn.joblib')
# Out:
# ['knn.joblib']

# %%
model=joblib.load('knn.joblib')

# %%
accuracy_score(p1,ytrain)*100
# Out:
# 91.46341463414635

# %%
model.predict
# Out:
# <bound method KNeighborsClassifier.predict of KNeighborsClassifier()>

# %%
#gui it should take a list of values and when predict button it should predict the values

# %%
from tkinter import *
import joblib
window=Tk()
window.title('flood')
window.geometry('400x600')
l0=Label(window,text='jan')
l0.grid(row=0,column=1)
e0=Entry(window)
e0.grid(row=0,column=2)


l1=Label(window,text='frb')
l1.grid(row=1,column=1)
e1=Entry(window)
e1.grid(row=1,column=2)


l2=Label(window,text='mar')
l2.grid(row=2,column=1)
e2=Entry(window)
e2.grid(row=2,column=2)


l3=Label(window,text='apr')
l3.grid(row=3,column=1)
e3=Entry(window)
e3.grid(row=3,column=2)


l4=Label(window,text='may')
l4.grid(row=4,column=1)
e4=Entry(window)
e4.grid(row=4,column=2)


l5=Label(window,text='jun')
l5.grid(row=5,column=1)
e5=Entry(window)
e5.grid(row=5,column=2)


l6=Label(window,text='jul')
l6.grid(row=6,column=1)
e6=Entry(window)
e6.grid(row=6,column=2)


l7=Label(window,text='aug')
l7.grid(row=7,column=1)
e7=Entry(window)
e7.grid(row=7,column=2)


l8=Label(window,text='sep')
l8.grid(row=8,column=1)
e8=Entry(window)
e8.grid(row=8,column=2)


l9=Label(window,text='octo')
l9.grid(row=9,column=1)
e9=Entry(window)
e9.grid(row=9,column=2)


l10=Label(window,text='nov')
l10.grid(row=10,column=1)
e10=Entry(window)
e10.grid(row=10,column=2)


l11=Label(window,text='dec')
l11.grid(row=11,column=1)
e11=Entry(window)
e11.grid(row=11,column=2)

def clicked():
    print('button clicked')
    jan=e0.get()
    frb=e1.get()
    mar=e2.get()
    apr=e3.get()
    may=e4.get()
    jun=e5.get()
    jul=e6.get()
    aug=e7.get()
    sep=e8.get()
    octo=e9.get()
    nov=e10.get()
    dec=e11.get()
    print(jan,frb,mar,apr,may,jun,jul,aug,sep,octo,nov,dec)
    model=joblib.load('knn.joblib')
    p=model.predict([[jan,frb,mar,apr,may,jun,jul,aug,sep,octo,nov,dec]])
    print(p)

b=Button(window,text='predict',command=clicked)
b.grid(row=12,column=1)
window.mainloop()
# Out:
# button clicked
# 123 454 675 4556 54 234 77686 86 767 6543 554 444
# ['YES']
# C:\Users\91636\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\91636\anaconda3\lib\site-packages\sklearn\base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
